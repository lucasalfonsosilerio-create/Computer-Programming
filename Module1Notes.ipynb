# %%
integervariable = 3
decimalvariable = 3.3
stringvariable = "STRING"
print(integervariable, decimalvariable, stringvariable)
# Out:
# 3 3.3 STRING

# %% [markdown]
# # I created 3 variables, their names are integervariable, decimalvariable, and stringvariable. integervariable is an integer, decimalvariable is a float, stringvariable is a string.
# # I used print to print them.

# %%
jar1 = 5
jar2 = 10
hi = "hello"
print(jar1 + jar2 + hi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 jar1 = 5
#       2 jar2 = 10
#       3 hi = "hello"
# ----> 4 print(jar1 + jar2 + hi)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Mixing operators between numbers, decimals and/or integers, and strings aren't is not supported. It will cause an error.

# %%
jar1 = 5
jar2 = 10
print(jar2)

jar2 = jar1
print(jar2)

# %% [markdown]
# # You can reassign the values of variables.

# %%
name = "Lucas"
age = 17
print("My name is",name,"and I am", age, "years old.")

# %% [markdown]
# # You can combine strings and variables with commas.

# %%
boolean = True
boolean2 = False

print(boolean, boolean2)
# Out:
# True False

# %% [markdown]
# # You can set a variable to either True or False, without strings.

# %%
my_Name = "Lucas"
my_Life = "title of my life"

print(my_Name.upper(),my_Name.lower(), my_Life.title())
# Out:
# LUCAS lucas Title Of My Life

# %% [markdown]
# ### Methods can change the value of a variable. For example, .title(), capitalizes each word, .upper(), capitalizes every letter, and .lower(), puts everything in lowercase. Print, however, is a function, as I use it by itself compared to methods.

# %%
fname = "Lucas"
lname = "Silerio"
fullname = f"{fname} {lname}"
print(fullname)
# Out:
# Lucas Silerio

# %% [markdown]
# ### "f strings" require both an f and the curly braces in quotes.

# %%
first_name = "emi"
last_name = "silerio"
full_name = f"{first_name} {last_name}"
print(f"Hello! My name is {full_name.title()}!")
# Out:
# Hello! My name is Emi Silerio!

# %% [markdown]
# ### you can combine commands

# %%
print("Groceries:\n\tMilk\nBananas\nButter\nBread\nMeat")
# Out:
# Groceries:
# 	Milk
# Bananas
# Butter
# Bread
# Meat

# %% [markdown]
# ### \n is an escape key, \t is used for tabbing

# %%
# there are 3 methods to clean whitespace: rstrip(), lstrip(), and strip()
name2 = " Lucas Silerio "
name2cleaned = name2.strip().upper()
print(name2)
print(name2cleaned)
# Out:
#  Lucas Silerio
# LUCAS SILERIO

# %% [markdown]
# #### there are 3 methods to clean whitespace: rstrip(), lstrip(), and strip()
